# %%
import pandas as pd
from common.unit_test import *
import numpy as np

# %%
dhl_df = pd.read_csv("DHL_Facilities.csv")
#TODO This step should probably be read into a raw S3 Bucket first

# %%
#TODO this step should be re-pulling this information from raw.
dhl_df = dhl_df[['NAME',
                 'ADDRESS',
                 'CITY',
                 'STATE',
                 'ZIP',
                 'CENSUS_CODE',
                 'LATITUDE',
                 'LONGITUDE',
                 'LOCATION_TY']]

# %%
#UNIT TESTS
check_column_matches_schema(dhl_df)

validate_column_rules(dhl_df)
# Out:
# {row: 0, column: "NAME"}: "nan" this field cannot be null
# False

# %%
#TODO once this data is validated to be confirmed, send it to curated S3 bucket

# %%
dhl_df
# Out:
#                          NAME                  ADDRESS            CITY STATE  \
# 0                         NaN                      NaN             NaN   NaN
# 1                 DHL STATION    5120 EAST LEE BIRD RD    NORTH PLATTE    NE
# 2               PC CONNECTION          450 MARLBORO ST           KEENE    NH
# 3               20 CENTRAL SQ            20 CENTRAL SQ           KEENE    NH
# 4              SHIPPING SHACK            63 EMERALD ST           KEENE    NH
# ...                       ...                      ...             ...   ...
# 24068         AAMES HOME LOAN       535 CENTERVILLE RD         WARWICK    RI
# 24069  FAMILY CHOICE MORTGAGE        2843 S COUNTY TRL  EAST GREENWICH    RI
# 24070   SALT POND OFFICE PARK          24 SALT POND RD       WAKEFIELD    RI
# 24071           BOATERS WORLD         684 KINGSTOWN RD       WAKEFIELD    RI
# 24072                SHIPMATE  36 S COUNTY COMMONS WAY       WAKEFIELD    RI
#
# ...
